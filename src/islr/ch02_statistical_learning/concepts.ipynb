# %% [markdown]
# # Chapter 2: Statistical Learning — Concepts
#
# **Topics:** What is statistical learning, prediction vs. inference, parametric vs. non-parametric models, bias-variance tradeoff, MSE decomposition, classification setting.

# %% [markdown]
# # Chapter 2: Statistical Learning — Applied Exercises
#
# Applied exercises from ISLR Chapter 2. Covers exploratory analysis, understanding the College and Auto datasets, and basic KNN.

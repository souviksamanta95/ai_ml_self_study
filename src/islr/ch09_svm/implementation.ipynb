# %% [markdown]
# # Chapter 9: Support Vector Machines — From Scratch
#
# Implementing a linear SVM using the SMO-style update from scratch.
#
# **Goals:**
# - Hard-margin SVM: quadratic programming formulation
# - Soft-margin: slack variables, cost parameter C
# - Kernel trick: replace dot products with K(xᵢ, xⱼ)
# - Verify against sklearn's SVC

# %% [markdown]
# # Chapter 9: Support Vector Machines — Concepts
#
# **Topics:** Maximal margin classifier, support vectors, soft margin (support vector classifier), kernels (polynomial, radial), SVMs for multi-class, SVR.

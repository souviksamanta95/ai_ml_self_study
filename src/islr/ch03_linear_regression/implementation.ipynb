# %% [markdown]
# # Chapter 3: Linear Regression — From Scratch
#
# Implementing OLS linear regression using only numpy.
#
# **Goals:**
# - Derive and implement the normal equation: β = (XᵀX)⁻¹Xᵀy
# - Compute RSE, R², standard errors, t-statistics, p-values by hand
# - Verify results match `statsmodels.OLS`

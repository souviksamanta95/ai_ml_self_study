# %% [markdown]
# # Chapter 3: Linear Regression — Concepts
#
# **Topics:** Simple/multiple linear regression, OLS, RSE, R², F-statistic, coefficient interpretation, qualitative predictors, interaction terms, potential problems (non-linearity, heteroscedasticity, collinearity).

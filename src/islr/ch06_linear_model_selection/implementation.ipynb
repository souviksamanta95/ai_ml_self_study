# %% [markdown]
# # Chapter 6: Linear Model Selection & Regularization — From Scratch
#
# Implementing ridge and lasso regression from scratch using numpy.
#
# **Goals:**
# - Ridge: closed-form solution β = (XᵀX + λI)⁻¹Xᵀy
# - Lasso: coordinate descent algorithm
# - Plot coefficient paths as λ varies
# - Verify against sklearn's Ridge and Lasso

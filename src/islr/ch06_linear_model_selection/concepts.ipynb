# %% [markdown]
# # Chapter 6: Linear Model Selection & Regularization — Concepts
#
# **Topics:** Best subset selection, stepwise selection, Cp/AIC/BIC/adjusted R², ridge regression, lasso, selecting λ via CV, dimension reduction (PCR, PLS).

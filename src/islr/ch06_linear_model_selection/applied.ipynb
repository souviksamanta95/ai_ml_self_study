# %% [markdown]
# # Chapter 6: Linear Model Selection & Regularization — Applied Exercises
#
# Applied exercises from ISLR Chapter 6. Uses Hitters and College datasets. Ridge, lasso, PCR, PLS with CV.

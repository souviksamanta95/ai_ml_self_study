# %% [markdown]
# # Chapter 10: Deep Learning — Concepts
#
# **Topics:** Single/multi-layer neural networks, activation functions, forward/backward pass, SGD, regularization (dropout, batch norm), CNNs (convolution, pooling), RNNs and LSTMs, document classification.

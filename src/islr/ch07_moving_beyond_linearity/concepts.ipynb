# %% [markdown]
# # Chapter 7: Moving Beyond Linearity — Concepts
#
# **Topics:** Polynomial regression, step functions, regression splines, smoothing splines, local regression, generalized additive models (GAMs).

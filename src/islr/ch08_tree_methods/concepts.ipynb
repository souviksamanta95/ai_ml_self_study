# %% [markdown]
# # Chapter 8: Tree-Based Methods — Concepts
#
# **Topics:** Decision trees (regression and classification), pruning, bagging, random forests (decorrelating trees), boosting (sequential fitting), BART.

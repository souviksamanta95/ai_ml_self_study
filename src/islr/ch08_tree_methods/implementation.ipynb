# %% [markdown]
# # Chapter 8: Tree-Based Methods — From Scratch
#
# Implementing a decision tree and bagging from scratch using only numpy.
#
# **Goals:**
# - Build a CART decision tree (recursive binary splitting, Gini/RSS)
# - Cost-complexity pruning
# - Bagging: bootstrap aggregation over trees
# - Verify against sklearn's DecisionTreeClassifier

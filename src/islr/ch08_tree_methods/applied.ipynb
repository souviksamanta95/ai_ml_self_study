# %% [markdown]
# # Chapter 8: Tree-Based Methods — Applied Exercises
#
# Applied exercises from ISLR Chapter 8. Decision trees, bagging, random forests, and boosting on Carseats and Boston datasets.

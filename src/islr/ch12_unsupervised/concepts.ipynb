# %% [markdown]
# # Chapter 12: Unsupervised Learning — Concepts
#
# **Topics:** PCA (loadings, scores, variance explained, scree plot), matrix completion, K-means clustering, hierarchical clustering (linkage methods, dendrograms), practical considerations.

# %% [markdown]
# # Chapter 12: Unsupervised Learning — From Scratch
#
# Implementing PCA and K-means from scratch using only numpy.
#
# **Goals:**
# - PCA via SVD: compute loadings, scores, proportion of variance explained
# - K-means: assignment and update steps, convergence, sensitivity to initialization
# - Verify PCA against sklearn's PCA

# %% [markdown]
# # Chapter 5: Resampling Methods — From Scratch
#
# Implementing k-fold CV and bootstrap from scratch using only numpy.
#
# **Goals:**
# - Manual k-fold cross-validation loop
# - Bootstrap confidence intervals for OLS coefficients
# - Compare bootstrap SE to OLS analytical SE

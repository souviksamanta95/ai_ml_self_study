# %% [markdown]
# # Chapter 5: Resampling Methods — Concepts
#
# **Topics:** Why resampling, validation set approach, LOOCV, k-fold cross-validation, bias-variance tradeoff in CV, bootstrap for standard error estimation.

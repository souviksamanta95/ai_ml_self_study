# %% [markdown]
# # Chapter 4: Classification — From Scratch
#
# Implementing logistic regression and LDA from scratch using only numpy.
#
# **Goals:**
# - Logistic regression via gradient descent (no sklearn)
# - LDA: estimate class priors, means, shared covariance; compute discriminant scores
# - Evaluate with confusion matrix, precision, recall, ROC/AUC

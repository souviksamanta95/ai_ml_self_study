# %% [markdown]
# # Chapter 4: Classification — Concepts
#
# **Topics:** Why not linear regression for classification, logistic regression, maximum likelihood estimation, multiple logistic regression, LDA, QDA, Naive Bayes, KNN, comparison of methods.
